# %% [markdown]
# # charge bibliotique

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from dotenv import load_dotenv
import os

# %% [markdown]
# ##import data

# %%
#connexion:
load_dotenv()  # installer .env
user = os.getenv("DB_USER")
password = os.getenv("DB_PASSWORD")
host = os.getenv("DB_HOST")
port = os.getenv("DB_PORT")
db = os.getenv("DB_NAME")
DATABASE_URL = f"postgresql://{user}:{password}@{host}:{port}/{db}"
engine = create_engine(DATABASE_URL)
print("conexion ok")
df=pd.read_sql("select * from staging.jumia_data_raw",engine)
# Out:
# conexion ok

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Force 14-inch Laptop Daily Backpack For Unisex...
# 1              1  Force Daily Backpack Laptop 14" For Unisex - D...
# 2              2  Force 14-inch Laptop Daily Backpack For Unisex...
# 3              3  Force 14-inch Laptop Daily Backpack For Unisex...
# 4              4   Force Daily Backpack Laptop 14" For Unisex - Nod
# ...          ...                                                ...
# 1999         194      TAT Laptop Sleeve Case Cover Bag – Multicolor
# 2000         195          SG SGLaptop  - For 17 Inch Laptop - Black
# 2001         197  Samsung LC34G55TWWMXZN 34 Inch Odyssey WQHD 16...
# 2002         198  Msa Fingerprint USB 3.0 Flash Drive (32GB) - D...
# 2003         199  Apple  MagSafe 2 Power Adapter For MacBook Pro...
#
#                     new_price   old_price percent_discount  rate  \
# 0                  EGP 159.00  EGP 299.00              47%   4.2
# 1                  EGP 159.00  EGP 245.00              35%   4.4
# 2                  EGP 159.00  EGP 245.00              35%   4.3
# 3                  EGP 159.00  EGP 245.00              35%   4.3
# 4                  EGP 159.00  EGP 245.00              35%   4.5
# ...                       ...         ...              ...   ...
# 1999  EGP 199.00 - EGP 225.00  EGP 350.00              43%   NaN
# 2000               EGP 580.00        None             None   NaN
# 2001            EGP 17,999.00        None             None   NaN
# 2002               EGP 650.00        None             None   NaN
# 2003             EGP 2,200.00        None             None   5.0
#
#       verified_ratings saler_score  Followers Order Fulfillment_Rate  \
# 0                757.0        100%     1085.0              Excellent
# 1                109.0        100%     1085.0              Excellent
# 2                134.0        100%     1085.0              Excellent
# 3                128.0        100%     1085.0              Excellent
# 4                117.0        100%     1085.0              Excellent
# ...                ...         ...        ...                    ...
# 1999               NaN         94%       78.0              Excellent
# 2000               NaN         60%        NaN                   None
# 2001               NaN        100%       84.0              Excellent
# 2002               NaN         50%       30.0              Excellent
# 2003               2.0         20%      431.0              Very Poor
#
#      Quality Score Customer Rating  \
# 0        Excellent       Excellent
# 1        Excellent       Excellent
# 2        Excellent       Excellent
# 3        Excellent       Excellent
# 4        Excellent       Excellent
# ...            ...             ...
# 1999          Good       Excellent
# 2000          None            None
# 2001     Excellent            None
# 2002     Very Poor            None
# 2003     Very Poor         Average
#
#                                                    link  page_number
# 0     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 1     https://www.jumia.com.eg/force-daily-backpack-...          1.0
# 2     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 3     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 4     https://www.jumia.com.eg/daily-backpack-for-un...          1.0
# ...                                                 ...          ...
# 1999  https://www.jumia.com.eg/tat-laptop-sleeve-cas...         50.0
# 2000  https://www.jumia.com.eg/sg-sglaptop-for-17-in...         50.0
# 2001  https://www.jumia.com.eg/samsung-lc34g55twwmxz...         50.0
# 2002  https://www.jumia.com.eg/fingerprint-usb-3.0-f...         50.0
# 2003  https://www.jumia.com.eg/60w-magsafe-2-power-a...         50.0
#
# [2004 rows x 14 columns]

# %%
df.info() 
df.columns
df.shape
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              2004 non-null   int64
#  1   name                    1998 non-null   object
#  2   new_price               1998 non-null   object
#  3   old_price               1512 non-null   object
#  4   percent_discount        1512 non-null   object
#  5   rate                    723 non-null    float64
#  6   verified_ratings        723 non-null    float64
#  7   saler_score             1963 non-null   object
#  8   Followers               1954 non-null   float64
#  9   Order Fulfillment_Rate  1918 non-null   object
#  10  Quality Score           1918 non-null   object
#  11  Customer Rating         1483 non-null   object
#  12  link                    1999 non-null   object
#  13  page_number             1999 non-null   float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 219.3+ KB
#    Unnamed: 0                                               name   new_price  \
# 0           0  Force 14-inch Laptop Daily Backpack For Unisex...  EGP 159.00
# 1           1  Force Daily Backpack Laptop 14" For Unisex - D...  EGP 159.00
# 2           2  Force 14-inch Laptop Daily Backpack For Unisex...  EGP 159.00
# 3           3  Force 14-inch Laptop Daily Backpack For Unisex...  EGP 159.00
# 4           4   Force Daily Backpack Laptop 14" For Unisex - Nod  EGP 159.00
#
#     old_price percent_discount  rate  verified_ratings saler_score  Followers  \
# 0  EGP 299.00              47%   4.2             757.0        100%     1085.0
# 1  EGP 245.00              35%   4.4             109.0        100%     1085.0
# 2  EGP 245.00              35%   4.3             134.0        100%     1085.0
# 3  EGP 245.00              35%   4.3             128.0        100%     1085.0
# 4  EGP 245.00              35%   4.5             117.0        100%     1085.0
#
#   Order Fulfillment_Rate Quality Score Customer Rating  \
# 0              Excellent     Excellent       Excellent
# 1              Excellent     Excellent       Excellent
# 2              Excellent     Excellent       Excellent
# 3              Excellent     Excellent       Excellent
# 4              Excellent     Excellent       Excellent
#
#                                                 link  page_number
# 0  https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 1  https://www.jumia.com.eg/force-daily-backpack-...          1.0
# 2  https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 3  https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 4  https://www.jumia.com.eg/daily-backpack-for-un...          1.0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# name                         6
# new_price                    6
# old_price                  492
# percent_discount           492
# rate                      1281
# verified_ratings          1281
# saler_score                 41
# Followers                   50
# Order Fulfillment_Rate      86
# Quality Score               86
# Customer Rating            521
# link                         5
# page_number                  5
# dtype: int64

# %% [markdown]
# ## nettoyage

# %%
df
# Out:
#       Unnamed: 0                                               name  \
# 0              0  Force 14-inch Laptop Daily Backpack For Unisex...
# 1              1  Force Daily Backpack Laptop 14" For Unisex - D...
# 2              2  Force 14-inch Laptop Daily Backpack For Unisex...
# 3              3  Force 14-inch Laptop Daily Backpack For Unisex...
# 4              4   Force Daily Backpack Laptop 14" For Unisex - Nod
# ...          ...                                                ...
# 1999         194      TAT Laptop Sleeve Case Cover Bag – Multicolor
# 2000         195          SG SGLaptop  - For 17 Inch Laptop - Black
# 2001         197  Samsung LC34G55TWWMXZN 34 Inch Odyssey WQHD 16...
# 2002         198  Msa Fingerprint USB 3.0 Flash Drive (32GB) - D...
# 2003         199  Apple  MagSafe 2 Power Adapter For MacBook Pro...
#
#                     new_price   old_price percent_discount  rate  \
# 0                  EGP 159.00  EGP 299.00              47%   4.2
# 1                  EGP 159.00  EGP 245.00              35%   4.4
# 2                  EGP 159.00  EGP 245.00              35%   4.3
# 3                  EGP 159.00  EGP 245.00              35%   4.3
# 4                  EGP 159.00  EGP 245.00              35%   4.5
# ...                       ...         ...              ...   ...
# 1999  EGP 199.00 - EGP 225.00  EGP 350.00              43%   NaN
# 2000               EGP 580.00        None             None   NaN
# 2001            EGP 17,999.00        None             None   NaN
# 2002               EGP 650.00        None             None   NaN
# 2003             EGP 2,200.00        None             None   5.0
#
#       verified_ratings saler_score  Followers Order Fulfillment_Rate  \
# 0                757.0        100%     1085.0              Excellent
# 1                109.0        100%     1085.0              Excellent
# 2                134.0        100%     1085.0              Excellent
# 3                128.0        100%     1085.0              Excellent
# 4                117.0        100%     1085.0              Excellent
# ...                ...         ...        ...                    ...
# 1999               NaN         94%       78.0              Excellent
# 2000               NaN         60%        NaN                   None
# 2001               NaN        100%       84.0              Excellent
# 2002               NaN         50%       30.0              Excellent
# 2003               2.0         20%      431.0              Very Poor
#
#      Quality Score Customer Rating  \
# 0        Excellent       Excellent
# 1        Excellent       Excellent
# 2        Excellent       Excellent
# 3        Excellent       Excellent
# 4        Excellent       Excellent
# ...            ...             ...
# 1999          Good       Excellent
# 2000          None            None
# 2001     Excellent            None
# 2002     Very Poor            None
# 2003     Very Poor         Average
#
#                                                    link  page_number
# 0     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 1     https://www.jumia.com.eg/force-daily-backpack-...          1.0
# 2     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 3     https://www.jumia.com.eg/14-inch-laptop-daily-...          1.0
# 4     https://www.jumia.com.eg/daily-backpack-for-un...          1.0
# ...                                                 ...          ...
# 1999  https://www.jumia.com.eg/tat-laptop-sleeve-cas...         50.0
# 2000  https://www.jumia.com.eg/sg-sglaptop-for-17-in...         50.0
# 2001  https://www.jumia.com.eg/samsung-lc34g55twwmxz...         50.0
# 2002  https://www.jumia.com.eg/fingerprint-usb-3.0-f...         50.0
# 2003  https://www.jumia.com.eg/60w-magsafe-2-power-a...         50.0
#
# [2004 rows x 14 columns]
